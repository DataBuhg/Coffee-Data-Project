# %%
import pandas as pd

# %%
df = pd.read_csv("coffeesales.csv")
df
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 1203  2024-08-08  2024-08-08 12:43:19.558      card  ANON-0000-0000-0141
# 1204  2024-08-08  2024-08-08 12:44:14.953      card  ANON-0000-0000-0141
# 1205  2024-08-08  2024-08-08 16:57:53.266      card  ANON-0000-0000-0473
# 1206  2024-08-08  2024-08-08 17:17:51.749      card  ANON-0000-0000-0474
# 1207  2024-08-08  2024-08-08 21:25:59.265      card  ANON-0000-0000-0311
#
#       money          coffee_name
# 0     38.70                Latte
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1208 non-null   object
#  1   datetime     1208 non-null   object
#  2   cash_type    1208 non-null   object
#  3   card         1119 non-null   object
#  4   money        1208 non-null   float64
#  5   coffee_name  1208 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 56.8+ KB

# %%
df = df[['date','cash_type', 'card', 'money', 'coffee_name']].copy()
df
# Out:
#             date cash_type                 card  money          coffee_name
# 0     2024-03-01      card  ANON-0000-0000-0001  38.70                Latte
# 1     2024-03-01      card  ANON-0000-0000-0002  38.70        Hot Chocolate
# 2     2024-03-01      card  ANON-0000-0000-0002  38.70        Hot Chocolate
# 3     2024-03-01      card  ANON-0000-0000-0003  28.90            Americano
# 4     2024-03-01      card  ANON-0000-0000-0004  38.70                Latte
# ...          ...       ...                  ...    ...                  ...
# 1203  2024-08-08      card  ANON-0000-0000-0141  23.02              Cortado
# 1204  2024-08-08      card  ANON-0000-0000-0141  23.02              Cortado
# 1205  2024-08-08      card  ANON-0000-0000-0473  32.82           Cappuccino
# 1206  2024-08-08      card  ANON-0000-0000-0474  32.82           Cappuccino
# 1207  2024-08-08      card  ANON-0000-0000-0311  27.92  Americano with Milk
#
# [1208 rows x 5 columns]

# %%
df.dtypes
# Out:
# date            object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# date           datetime64[ns]
# cash_type              object
# card                   object
# money                 float64
# coffee_name            object
# dtype: object

# %%
#df.to_csv('coffeeSales.csv', index=False)

# %%
dfit = df.iterrows()
for x, y in dfit:
    print(y)
# Out:
# date           2024-03-01 00:00:00
# cash_type                     card
# card           ANON-0000-0000-0001
# money                         38.7
# coffee_name                  Latte
# Name: 0, dtype: object
# date           2024-03-01 00:00:00
# cash_type                     card
# card           ANON-0000-0000-0002
# money                         38.7
# coffee_name          Hot Chocolate
# Name: 1, dtype: object
# date           2024-03-01 00:00:00
# cash_type                     card
# card           ANON-0000-0000-0002
# money                         38.7
# coffee_name          Hot Chocolate
# Name: 2, dtype: object
# date           2024-03-01 00:00:00
# cash_type                     card
# card           ANON-0000-0000-0003
# money                         28.9
# coffee_name              Americano
# Name: 3, dtype: object
# date           2024-03-01 00:00:00
# cash_type                     card
# card           ANON-0000-0000-0004
# money                         38.7
# ...

# %%
df =  pd.read_csv("coffeesales.csv")
df
# Out:
#             date cash_type                 card  money          coffee_name
# 0     2024-03-01      card  ANON-0000-0000-0001  38.70                Latte
# 1     2024-03-01      card  ANON-0000-0000-0002  38.70        Hot Chocolate
# 2     2024-03-01      card  ANON-0000-0000-0002  38.70        Hot Chocolate
# 3     2024-03-01      card  ANON-0000-0000-0003  28.90            Americano
# 4     2024-03-01      card  ANON-0000-0000-0004  38.70                Latte
# ...          ...       ...                  ...    ...                  ...
# 1203  2024-08-08      card  ANON-0000-0000-0141  23.02              Cortado
# 1204  2024-08-08      card  ANON-0000-0000-0141  23.02              Cortado
# 1205  2024-08-08      card  ANON-0000-0000-0473  32.82           Cappuccino
# 1206  2024-08-08      card  ANON-0000-0000-0474  32.82           Cappuccino
# 1207  2024-08-08      card  ANON-0000-0000-0311  27.92  Americano with Milk
#
# [1208 rows x 5 columns]

# %%
df.dtypes
# Out:
# date            object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object
